# %%
import pandas as pd

# %%
#DATA PREPOCEESING OR DATA CLEANING

#basic motive of pandas is to clean data to obtain useful insights from data

# %%
df=pd.read_csv('PALM_BEACH.csv')
df
# Out:
#                             EMPLOYER                      ADDRESS1  ADDRESS2  \
# 0          PERIODONTAL ASSOCIATES PA  7301 A. WEST PALMETTO PK RD.       NaN
# 1  PERSONALIZED AIR CONDITIONING INC                159 NW 11TH ST       NaN
# 2                 PETER J LOWE MD PA     4175 S CONGRESS AVE STE V       NaN
#
#          CITY    ZIP  ST                          Website            Phone  \
# 0  BOCA RATON  33433  FL  https://www.flperioimplant.com/  +1 561-394-4519
# 1  BOCA RATON  33432  FL        http://generatortogo.com/  +1 866-221-8100
# 2  LAKE WORTH  33461  FL      https://retinaleyecare.com/  +1 561-967-8000
#
#                      Email
# 0  info@flperioimplant.com
# 1   info@ppsgenerators.com
# 2  info@retinaleyecare.com

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['EMPLOYER', 'ADDRESS1', 'ADDRESS2', 'CITY', 'ZIP', 'ST', 'Website',
#        'Phone', 'Email'],
#       dtype='object')

# %%
df=pd.read_csv('PALM_BEACH.csv',nrows=1)
df
# Out:
#                     EMPLOYER                      ADDRESS1  ADDRESS2  \
# 0  PERIODONTAL ASSOCIATES PA  7301 A. WEST PALMETTO PK RD.       NaN
#
#          CITY    ZIP  ST                          Website            Phone  \
# 0  BOCA RATON  33433  FL  https://www.flperioimplant.com/  +1 561-394-4519
#
#                      Email
# 0  info@flperioimplant.com

# %%
df=pd.read_csv('PALM_BEACH.csv',usecols=[0])
df
# Out:
#                             EMPLOYER
# 0          PERIODONTAL ASSOCIATES PA
# 1  PERSONALIZED AIR CONDITIONING INC
# 2                 PETER J LOWE MD PA

# %%
df=pd.read_csv('PALM_BEACH.csv',usecols=[0,1])
df
# Out:
#                             EMPLOYER                      ADDRESS1
# 0          PERIODONTAL ASSOCIATES PA  7301 A. WEST PALMETTO PK RD.
# 1  PERSONALIZED AIR CONDITIONING INC                159 NW 11TH ST
# 2                 PETER J LOWE MD PA     4175 S CONGRESS AVE STE V

# %%
df=pd.read_csv('PALM_BEACH.csv',usecols=[0,7,8])
df
# Out:
#                             EMPLOYER            Phone                    Email
# 0          PERIODONTAL ASSOCIATES PA  +1 561-394-4519  info@flperioimplant.com
# 1  PERSONALIZED AIR CONDITIONING INC  +1 866-221-8100   info@ppsgenerators.com
# 2                 PETER J LOWE MD PA  +1 561-967-8000  info@retinaleyecare.com

# %%
#header ky oper khuch data
df=pd.read_csv('sample_data.csv')
df
# Out:
#           0         1         2
# 0  column_a  column_b  column_c
# 1         1         1        10
# 2         2         4         8
# 3         3         9         6
# 4         4        16         4
# 5         5        25         2

# %%
df=pd.read_csv('sample_data.csv',skiprows=1)
df
# Out:
#    column_a  column_b  column_c
# 0         1         1        10
# 1         2         4         8
# 2         3         9         6
# 3         4        16         4
# 4         5        25         2

# %%
df=pd.read_csv('sample_data.csv',skiprows=2)
df
# Out:
#    1  1.1  10
# 0  2    4   8
# 1  3    9   6
# 2  4   16   4
# 3  5   25   2

# %%
df=pd.read_csv('sample_data.csv',skiprows=[2,4])
df
# Out:
#           0         1         2
# 0  column_a  column_b  column_c
# 1         2         4         8
# 2         4        16         4
# 3         5        25         2

# %%
df=pd.read_csv('sample_data.csv')
df
# Out:
#           0         1         2
# 0  column_a  column_b  column_c
# 1         1         1        10
# 2         2         4         8
# 3         3         9         6
# 4         4        16         4
# 5         5        25         2

# %%
df=pd.read_csv('PALM_BEACH.csv')
df
# Out:
#                             EMPLOYER                      ADDRESS1  ADDRESS2  \
# 0          PERIODONTAL ASSOCIATES PA  7301 A. WEST PALMETTO PK RD.       NaN
# 1  PERSONALIZED AIR CONDITIONING INC                159 NW 11TH ST       NaN
# 2                 PETER J LOWE MD PA     4175 S CONGRESS AVE STE V       NaN
#
#          CITY    ZIP  ST                          Website            Phone  \
# 0  BOCA RATON  33433  FL  https://www.flperioimplant.com/  +1 561-394-4519
# 1  BOCA RATON  33432  FL        http://generatortogo.com/  +1 866-221-8100
# 2  LAKE WORTH  33461  FL      https://retinaleyecare.com/  +1 561-967-8000
#
#                      Email
# 0  info@flperioimplant.com
# 1   info@ppsgenerators.com
# 2  info@retinaleyecare.com

# %%
df=pd.read_csv('PALM_BEACH.csv',index_col='EMPLOYER')
df
# Out:
#                                                        ADDRESS1  ADDRESS2  \
# EMPLOYER
# PERIODONTAL ASSOCIATES PA          7301 A. WEST PALMETTO PK RD.       NaN
# PERSONALIZED AIR CONDITIONING INC                159 NW 11TH ST       NaN
# PETER J LOWE MD PA                    4175 S CONGRESS AVE STE V       NaN
#
#                                          CITY    ZIP  ST  \
# EMPLOYER
# PERIODONTAL ASSOCIATES PA          BOCA RATON  33433  FL
# PERSONALIZED AIR CONDITIONING INC  BOCA RATON  33432  FL
# PETER J LOWE MD PA                 LAKE WORTH  33461  FL
#
#                                                            Website  \
# EMPLOYER
# PERIODONTAL ASSOCIATES PA          https://www.flperioimplant.com/
# PERSONALIZED AIR CONDITIONING INC        http://generatortogo.com/
# PETER J LOWE MD PA                     https://retinaleyecare.com/
#
#                                              Phone                    Email
# EMPLOYER
# ...

# %%
#header prefic names
pd.read_csv("Fortune_10.csv")
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
pd.read_csv("Fortune_10.csv")
# Out:
#      0                1                    2          3             4  \
# 0   ID             Name             Industry  Inception       Revenue
# 1    1          Lamtone          IT Services       2009  $11,757,018
# 2    2        Stripfind   Financial Services       2010  $12,329,371
# 3    3  Canecorporation               Health       2012  $10,597,009
# 4    4         Mattouch          IT Services       2013  $14,026,934
# 5    5        Techdrill               Health       2009  $10,573,990
# 6    6         Techline               Health       2006  $13,898,119
# 7    7          Cityace               Health       2010   $9,254,614
# 8    8   Kayelectronics               Health       2009   $9,451,943
# 9    9          Ganzlax          IT Services       2011  $14,001,180
# 10  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     5         6       7
# 0            Expenses    Profit  Growth
# 1   6,482,465 Dollars   5274553     30%
# ...

# %%
pd.read_csv("Fortune_10.csv" ,header=1)
# Out:
#    ID             Name             Industry  Inception       Revenue  \
# 0   1          Lamtone          IT Services       2009  $11,757,018
# 1   2        Stripfind   Financial Services       2010  $12,329,371
# 2   3  Canecorporation               Health       2012  $10,597,009
# 3   4         Mattouch          IT Services       2013  $14,026,934
# 4   5        Techdrill               Health       2009  $10,573,990
# 5   6         Techline               Health       2006  $13,898,119
# 6   7          Cityace               Health       2010   $9,254,614
# 7   8   Kayelectronics               Health       2009   $9,451,943
# 8   9          Ganzlax          IT Services       2011  $14,001,180
# 9  10      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    20%
# 2  7,591,189 Dollars   3005820     7%
# 3  7,429,377 Dollars   6597557    26%
# ...

# %%
#unamed if only 1 col heading exist
#if no heading exist  give header=none

# %%
pd.read_csv("Fortune_10.csv" ,header=None,prefix="Columns")
# Out:
#    Columns0         Columns1             Columns2   Columns3      Columns4  \
# 0         0                1                    2          3             4
# 1        ID             Name             Industry  Inception       Revenue
# 2         1          Lamtone          IT Services       2009  $11,757,018
# 3         2        Stripfind   Financial Services       2010  $12,329,371
# 4         3  Canecorporation               Health       2012  $10,597,009
# 5         4         Mattouch          IT Services       2013  $14,026,934
# 6         5        Techdrill               Health       2009  $10,573,990
# 7         6         Techline               Health       2006  $13,898,119
# 8         7          Cityace               Health       2010   $9,254,614
# 9         8   Kayelectronics               Health       2009   $9,451,943
# 10        9          Ganzlax          IT Services       2011  $14,001,180
# 11       10      Trantraxlax  Government Services       2011  $11,088,336
#
# ...

# %%
pd.read_csv("Fortune_10.csv" ,names=["A","B","C","D","E","F","G","H"])
# Out:
#      A                B                    C          D             E  \
# 0    0                1                    2          3             4
# 1   ID             Name             Industry  Inception       Revenue
# 2    1          Lamtone          IT Services       2009  $11,757,018
# 3    2        Stripfind   Financial Services       2010  $12,329,371
# 4    3  Canecorporation               Health       2012  $10,597,009
# 5    4         Mattouch          IT Services       2013  $14,026,934
# 6    5        Techdrill               Health       2009  $10,573,990
# 7    6         Techline               Health       2006  $13,898,119
# 8    7          Cityace               Health       2010   $9,254,614
# 9    8   Kayelectronics               Health       2009   $9,451,943
# 10   9          Ganzlax          IT Services       2011  $14,001,180
# 11  10      Trantraxlax  Government Services       2011  $11,088,336
#
#                     F         G       H
# ...
