# %% [markdown]
# # Read tabular data file

# %%
import pandas as pd

# %%
pd.read_table("http://bit.ly/chiporders")
# Out:
#       order_id  quantity                              item_name  \
# 0            1         1           Chips and Fresh Tomato Salsa
# 1            1         1                                   Izze
# 2            1         1                       Nantucket Nectar
# 3            1         1  Chips and Tomatillo-Green Chili Salsa
# 4            2         2                           Chicken Bowl
# ...        ...       ...                                    ...
# 4617      1833         1                          Steak Burrito
# 4618      1833         1                          Steak Burrito
# 4619      1834         1                     Chicken Salad Bowl
# 4620      1834         1                     Chicken Salad Bowl
# 4621      1834         1                     Chicken Salad Bowl
#
#                                      choice_description item_price
# 0                                                   NaN     $2.39
# 1                                          [Clementine]     $3.39
# 2                                               [Apple]     $3.39
# 3                                                   NaN     $2.39
# 4     [Tomatillo-Red Chili Salsa (Hot), [Black Beans...    $16.98
# ...                                                 ...        ...
# 4617  [Fresh Tomato Salsa, [Rice, Black Beans, Sour ...    $11.75
# 4618  [Fresh Tomato Salsa, [Rice, Sour Cream, Cheese...    $11.75
# 4619  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...    $11.25
# 4620  [Fresh Tomato Salsa, [Fajita Vegetables, Lettu...     $8.75
# 4621  [Fresh Tomato Salsa, [Fajita Vegetables, Pinto...     $8.75
#
# [4622 rows x 5 columns]

# %%
pd.read_table("http://bit.ly/movieusers")
# Out:
#           1|24|M|technician|85711
# 0              2|53|F|other|94043
# 1             3|23|M|writer|32067
# 2         4|24|M|technician|43537
# 3              5|33|F|other|15213
# 4          6|42|M|executive|98101
# ..                            ...
# 937        939|26|F|student|33319
# 938  940|32|M|administrator|02215
# 939        941|20|M|student|97229
# 940      942|48|F|librarian|78209
# 941        943|22|M|student|77841
#
# [942 rows x 1 columns]

# %%
col_name=["user_id","age ","gender","occupation","zip_code"]
pd.read_table("http://bit.ly/movieusers",sep="|",header=None,names=col_name)
# Out:
#      user_id  age  gender     occupation zip_code
# 0          1    24      M     technician    85711
# 1          2    53      F          other    94043
# 2          3    23      M         writer    32067
# 3          4    24      M     technician    43537
# 4          5    33      F          other    15213
# ..       ...   ...    ...            ...      ...
# 938      939    26      F        student    33319
# 939      940    32      M  administrator    02215
# 940      941    20      M        student    97229
# 941      942    48      F      librarian    78209
# 942      943    22      M        student    77841
#
# [943 rows x 5 columns]

# %% [markdown]
# ## Select Pandas series from a Dataframe

# %%
ufo_data=pd.read_csv("http://bit.ly//uforeports")
#uses comma as a default seperators

# %%
ufo_data.to_csv("ufo.csv", index = False)

# %%
type(ufo_data)
# Out:
# pandas.core.frame.DataFrame

# %%
ufo_data
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time
# 0        6/1/1930 22:00
# 1       6/30/1930 20:00
# 2       2/15/1931 14:00
# 3        6/1/1931 13:00
# 4       4/18/1933 19:00
# ...                 ...
# 18236  12/31/2000 23:00
# 18237  12/31/2000 23:00
# 18238  12/31/2000 23:45
# 18239  12/31/2000 23:45
# 18240  12/31/2000 23:59
#
# [18241 rows x 5 columns]

# %%
ufo_data["Colors Reported"]
# Out:
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#         ...
# 18236    NaN
# 18237    NaN
# 18238    NaN
# 18239    RED
# 18240    NaN
# Name: Colors Reported, Length: 18241, dtype: object

# %% [markdown]
# #### ADD A NEW SERIES

# %%
ufo_data["Location"]=ufo_data.City + "," +ufo_data.State

# %%
ufo_data
# Out:
#                        City Colors Reported Shape Reported State  \
# 0                    Ithaca             NaN       TRIANGLE    NY
# 1               Willingboro             NaN          OTHER    NJ
# 2                   Holyoke             NaN           OVAL    CO
# 3                   Abilene             NaN           DISK    KS
# 4      New York Worlds Fair             NaN          LIGHT    NY
# ...                     ...             ...            ...   ...
# 18236            Grant Park             NaN       TRIANGLE    IL
# 18237           Spirit Lake             NaN           DISK    IA
# 18238           Eagle River             NaN            NaN    WI
# 18239           Eagle River             RED          LIGHT    WI
# 18240                  Ybor             NaN           OVAL    FL
#
#                    Time                 Location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# 2       2/15/1931 14:00               Holyoke,CO
# 3        6/1/1931 13:00               Abilene,KS
# 4       4/18/1933 19:00  New York Worlds Fair,NY
# ...                 ...                      ...
# 18236  12/31/2000 23:00            Grant Park,IL
# 18237  12/31/2000 23:00           Spirit Lake,IA
# 18238  12/31/2000 23:45           Eagle River,WI
# 18239  12/31/2000 23:45           Eagle River,WI
# 18240  12/31/2000 23:59                  Ybor,FL
#
# [18241 rows x 6 columns]

# %% [markdown]
# ### PANDAS COMMANDS

# %%
movies=pd.read_csv("http://bit.ly//imdbratings")

# %%
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.describe() #descriptive Statistics #METHODS
# Out:
#        star_rating    duration
# count   979.000000  979.000000
# mean      7.889785  120.979571
# std       0.336069   26.218010
# min       7.400000   64.000000
# 25%       7.600000  102.000000
# 50%       7.800000  117.000000
# 75%       8.100000  134.000000
# max       9.300000  242.000000

# %%
movies.describe(include=["object"]) #dtype = object
# Out:
#                                   title content_rating  genre  \
# count                               979            976    979
# unique                              975             12     16
# top     The Girl with the Dragon Tattoo              R  Drama
# freq                                  2            460    278
#
#                                               actors_list
# count                                                 979
# unique                                                969
# top     [u'Daniel Radcliffe', u'Emma Watson', u'Rupert...
# freq                                                    6

# %%
movies.dtypes  #ATTRIBUTES
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
movies.shape #ATTRIBUTES
# Out:
# (979, 6)

# %% [markdown]
# # Rename columns

# %%
ufo_data.columns
# Out:
# Index(['City', 'Colors Reported', 'Shape Reported', 'State', 'Time',
#        'Location'],
#       dtype='object')

# %%
ufo_data.rename(columns={
    "Colors Reported" : "Color_Reported",
    "Shape Reported" : "Shaper_Reported",
}, inplace=True)

# %%
ufo_data
# Out:
#                        City Color_Reported Shaper_Reported State  \
# 0                    Ithaca            NaN        TRIANGLE    NY
# 1               Willingboro            NaN           OTHER    NJ
# 2                   Holyoke            NaN            OVAL    CO
# 3                   Abilene            NaN            DISK    KS
# 4      New York Worlds Fair            NaN           LIGHT    NY
# ...                     ...            ...             ...   ...
# 18236            Grant Park            NaN        TRIANGLE    IL
# 18237           Spirit Lake            NaN            DISK    IA
# 18238           Eagle River            NaN             NaN    WI
# 18239           Eagle River            RED           LIGHT    WI
# 18240                  Ybor            NaN            OVAL    FL
#
#                    Time                 Location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# 2       2/15/1931 14:00               Holyoke,CO
# 3        6/1/1931 13:00               Abilene,KS
# 4       4/18/1933 19:00  New York Worlds Fair,NY
# ...                 ...                      ...
# 18236  12/31/2000 23:00            Grant Park,IL
# 18237  12/31/2000 23:00           Spirit Lake,IA
# 18238  12/31/2000 23:45           Eagle River,WI
# 18239  12/31/2000 23:45           Eagle River,WI
# 18240  12/31/2000 23:59                  Ybor,FL
#
# [18241 rows x 6 columns]

# %% [markdown]
# ###### Modify all names

# %%
ufo_col=["city","color_reported","shape_reported","state","time","location",]

# %%
ufo_data.columns=ufo_col

# %%
ufo_data
# Out:
#                        city color_reported shape_reported state  \
# 0                    Ithaca            NaN       TRIANGLE    NY
# 1               Willingboro            NaN          OTHER    NJ
# 2                   Holyoke            NaN           OVAL    CO
# 3                   Abilene            NaN           DISK    KS
# 4      New York Worlds Fair            NaN          LIGHT    NY
# ...                     ...            ...            ...   ...
# 18236            Grant Park            NaN       TRIANGLE    IL
# 18237           Spirit Lake            NaN           DISK    IA
# 18238           Eagle River            NaN            NaN    WI
# 18239           Eagle River            RED          LIGHT    WI
# 18240                  Ybor            NaN           OVAL    FL
#
#                    time                 location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# 2       2/15/1931 14:00               Holyoke,CO
# 3        6/1/1931 13:00               Abilene,KS
# 4       4/18/1933 19:00  New York Worlds Fair,NY
# ...                 ...                      ...
# 18236  12/31/2000 23:00            Grant Park,IL
# 18237  12/31/2000 23:00           Spirit Lake,IA
# 18238  12/31/2000 23:45           Eagle River,WI
# 18239  12/31/2000 23:45           Eagle River,WI
# 18240  12/31/2000 23:59                  Ybor,FL
#
# [18241 rows x 6 columns]

# %% [markdown]
# ##### RENAME WHILE READING

# %%
# ufo_data=pd.read_csv("http://bit.ly//uforeports", names=ufo_col,header=0)

# %%
ufo_data
# Out:
#                        city color_reported shape_reported state  \
# 0                    Ithaca            NaN       TRIANGLE    NY
# 1               Willingboro            NaN          OTHER    NJ
# 2                   Holyoke            NaN           OVAL    CO
# 3                   Abilene            NaN           DISK    KS
# 4      New York Worlds Fair            NaN          LIGHT    NY
# ...                     ...            ...            ...   ...
# 18236            Grant Park            NaN       TRIANGLE    IL
# 18237           Spirit Lake            NaN           DISK    IA
# 18238           Eagle River            NaN            NaN    WI
# 18239           Eagle River            RED          LIGHT    WI
# 18240                  Ybor            NaN           OVAL    FL
#
#                    time                 location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# 2       2/15/1931 14:00               Holyoke,CO
# 3        6/1/1931 13:00               Abilene,KS
# 4       4/18/1933 19:00  New York Worlds Fair,NY
# ...                 ...                      ...
# 18236  12/31/2000 23:00            Grant Park,IL
# 18237  12/31/2000 23:00           Spirit Lake,IA
# 18238  12/31/2000 23:45           Eagle River,WI
# 18239  12/31/2000 23:45           Eagle River,WI
# 18240  12/31/2000 23:59                  Ybor,FL
#
# [18241 rows x 6 columns]

# %% [markdown]
# ####  Bonus

# %%
ufo_data.columns=ufo_data.columns.str.replace('_',"-")

# %%
ufo_data
# Out:
#                        city color-reported shape-reported state  \
# 0                    Ithaca            NaN       TRIANGLE    NY
# 1               Willingboro            NaN          OTHER    NJ
# 2                   Holyoke            NaN           OVAL    CO
# 3                   Abilene            NaN           DISK    KS
# 4      New York Worlds Fair            NaN          LIGHT    NY
# ...                     ...            ...            ...   ...
# 18236            Grant Park            NaN       TRIANGLE    IL
# 18237           Spirit Lake            NaN           DISK    IA
# 18238           Eagle River            NaN            NaN    WI
# 18239           Eagle River            RED          LIGHT    WI
# 18240                  Ybor            NaN           OVAL    FL
#
#                    time                 location
# 0        6/1/1930 22:00                Ithaca,NY
# 1       6/30/1930 20:00           Willingboro,NJ
# 2       2/15/1931 14:00               Holyoke,CO
# 3        6/1/1931 13:00               Abilene,KS
# 4       4/18/1933 19:00  New York Worlds Fair,NY
# ...                 ...                      ...
# 18236  12/31/2000 23:00            Grant Park,IL
# 18237  12/31/2000 23:00           Spirit Lake,IA
# 18238  12/31/2000 23:45           Eagle River,WI
# 18239  12/31/2000 23:45           Eagle River,WI
# 18240  12/31/2000 23:59                  Ybor,FL
#
# [18241 rows x 6 columns]

# %% [markdown]
# ## Remove Columns

# %%
ufo_data.drop("color-reported",axis=1,inplace=True) 
#1=col

# ufo_data.drop(["city","State"],axis=1,inplace=True)

# %%
ufo_data
# Out:
#                        city shape-reported state              time  \
# 0                    Ithaca       TRIANGLE    NY    6/1/1930 22:00
# 1               Willingboro          OTHER    NJ   6/30/1930 20:00
# 2                   Holyoke           OVAL    CO   2/15/1931 14:00
# 3                   Abilene           DISK    KS    6/1/1931 13:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# ...                     ...            ...   ...               ...
# 18236            Grant Park       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake           DISK    IA  12/31/2000 23:00
# 18238           Eagle River            NaN    WI  12/31/2000 23:45
# 18239           Eagle River          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor           OVAL    FL  12/31/2000 23:59
#
#                       location
# 0                    Ithaca,NY
# 1               Willingboro,NJ
# 2                   Holyoke,CO
# 3                   Abilene,KS
# 4      New York Worlds Fair,NY
# ...                        ...
# 18236            Grant Park,IL
# 18237           Spirit Lake,IA
# 18238           Eagle River,WI
# 18239           Eagle River,WI
# 18240                  Ybor,FL
#
# [18241 rows x 5 columns]

# %% [markdown]
# ### REMOVE ROWS

# %%
ufo_data.drop([0,2,3,5],axis=0,inplace=True)

# %%
ufo_data
# Out:
#                        city shape-reported state              time  \
# 1               Willingboro          OTHER    NJ   6/30/1930 20:00
# 4      New York Worlds Fair          LIGHT    NY   4/18/1933 19:00
# 6               Crater Lake         CIRCLE    CA    6/15/1935 0:00
# 7                      Alma           DISK    MI    7/15/1936 0:00
# 8                   Eklutna          CIGAR    AK  10/15/1936 17:00
# ...                     ...            ...   ...               ...
# 18236            Grant Park       TRIANGLE    IL  12/31/2000 23:00
# 18237           Spirit Lake           DISK    IA  12/31/2000 23:00
# 18238           Eagle River            NaN    WI  12/31/2000 23:45
# 18239           Eagle River          LIGHT    WI  12/31/2000 23:45
# 18240                  Ybor           OVAL    FL  12/31/2000 23:59
#
#                       location
# 1               Willingboro,NJ
# 4      New York Worlds Fair,NY
# 6               Crater Lake,CA
# 7                      Alma,MI
# 8                   Eklutna,AK
# ...                        ...
# 18236            Grant Park,IL
# 18237           Spirit Lake,IA
# 18238           Eagle River,WI
# 18239           Eagle River,WI
# 18240                  Ybor,FL
#
# [18237 rows x 5 columns]

# %% [markdown]
# # SORT SERIES

# %%
movies= pd.read_csv("http://bit.ly/imdbratings")

# %%
movies.to_csv('movies.csv',index=False)
movies.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %%
movies.title.sort_values()

#movies["title"].sort_vlaues()
#type(movies["title"].sort_vlaues()) #series 
#ascending=False
#it dose not change original data
# Out:
# 542     (500) Days of Summer
# 5               12 Angry Men
# 201         12 Years a Slave
# 698                127 Hours
# 110    2001: A Space Odyssey
#                ...
# 955         Zero Dark Thirty
# 677                   Zodiac
# 615               Zombieland
# 526                     Zulu
# 864                    [Rec]
# Name: title, Length: 979, dtype: object

# %% [markdown]
# ## Sort the data frame with particular column

# %%
movies.sort_values("title") #entire Dataframe
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...
# ..                                                 ...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
#
# [979 rows x 6 columns]

# %% [markdown]
# ###### old way to sort a series
# movies.title.order()
# ###### old way to sort a Dataframe
# movies.sort("titles")

# %% [markdown]
# ### Sort wtr to mutiple columns

# %%
movies.sort_values(["title","duration"])
# Out:
#      star_rating                  title content_rating      genre  duration  \
# 542          7.8   (500) Days of Summer          PG-13     Comedy        95
# 5            8.9           12 Angry Men      NOT RATED      Drama        96
# 201          8.1       12 Years a Slave              R  Biography       134
# 698          7.6              127 Hours              R  Adventure        94
# 110          8.3  2001: A Space Odyssey              G    Mystery       160
# ..           ...                    ...            ...        ...       ...
# 955          7.4       Zero Dark Thirty              R      Drama       157
# 677          7.7                 Zodiac              R      Crime       157
# 615          7.7             Zombieland              R     Comedy        88
# 526          7.8                   Zulu        UNRATED      Drama       138
# 864          7.5                  [Rec]              R     Horror        78
#
#                                            actors_list
# 542  [u'Zooey Deschanel', u'Joseph Gordon-Levitt', ...
# 5    [u'Henry Fonda', u'Lee J. Cobb', u'Martin Bals...
# 201  [u'Chiwetel Ejiofor', u'Michael Kenneth Willia...
# 698  [u'James Franco', u'Amber Tamblyn', u'Kate Mara']
# 110  [u'Keir Dullea', u'Gary Lockwood', u'William S...
# ..                                                 ...
# 955  [u'Jessica Chastain', u'Joel Edgerton', u'Chri...
# 677  [u'Jake Gyllenhaal', u'Robert Downey Jr.', u'M...
# 615  [u'Jesse Eisenberg', u'Emma Stone', u'Woody Ha...
# 526  [u'Stanley Baker', u'Jack Hawkins', u'Ulla Jac...
# 864  [u'Manuela Velasco', u'Ferran Terraza', u'Jorg...
#
# [979 rows x 6 columns]

# %% [markdown]
# # FILTER ROWS OF DF BY COL VALUE

# %% [raw]
# goal : all colums but row that have duration of 200
# we are going to create alist of boolen consiting true where duration is 200

# %%
booleans=[]
# series a mutable
for length in movies.duration:
    if length >=200:
        booleans.append(True)
    else :
        booleans.append(False)

# %%
len(booleans)
# Out:
# 979

# %%
#covert bolean list to pandas series

# %%
is_long = pd.Series(booleans)

# %%
movies[is_long] #display row only of 200>= duration
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 157              G      Drama       238
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
# 476          PG-13      Drama       242
# 630          PG-13  Biography       202
# 767       APPROVED     Action       205
#
#                                            actors_list
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %% [markdown]
# ## Another method

# %%
is_long= movies.duration>=200

# %%
#or
movies[ movies.duration>=200]
# Out:
#      star_rating                                          title  \
# 2            9.1                         The Godfather: Part II
# 7            8.9  The Lord of the Rings: The Return of the King
# 17           8.7                                  Seven Samurai
# 78           8.4                    Once Upon a Time in America
# 85           8.4                             Lawrence of Arabia
# 142          8.3              Lagaan: Once Upon a Time in India
# 157          8.2                             Gone with the Wind
# 204          8.1                                        Ben-Hur
# 445          7.9                           The Ten Commandments
# 476          7.8                                         Hamlet
# 630          7.7                                      Malcolm X
# 767          7.6                It's a Mad, Mad, Mad, Mad World
#
#     content_rating      genre  duration  \
# 2                R      Crime       200
# 7            PG-13  Adventure       201
# 17         UNRATED      Drama       207
# 78               R      Crime       229
# 85              PG  Adventure       216
# 142             PG  Adventure       224
# 157              G      Drama       238
# 204              G  Adventure       212
# 445       APPROVED  Adventure       220
# 476          PG-13      Drama       242
# 630          PG-13  Biography       202
# 767       APPROVED     Action       205
#
#                                            actors_list
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 7    [u'Elijah Wood', u'Viggo Mortensen', u'Ian McK...
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 78   [u'Robert De Niro', u'James Woods', u'Elizabet...
# 85   [u"Peter O'Toole", u'Alec Guinness', u'Anthony...
# 142  [u'Aamir Khan', u'Gracy Singh', u'Rachel Shell...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 204  [u'Charlton Heston', u'Jack Hawkins', u'Stephe...
# 445  [u'Charlton Heston', u'Yul Brynner', u'Anne Ba...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...
# 630  [u'Denzel Washington', u'Angela Bassett', u'De...
# 767  [u'Spencer Tracy', u'Milton Berle', u'Ethel Me...

# %% [markdown]
#   #####  Now if you only concern about genre col

# %%
movies[ movies.duration>=200].genre
#or
#movies[ movies.duration>=200].['genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %%
# or
movies.loc[ movies.duration>=200,'genre']
# Out:
# 2          Crime
# 7      Adventure
# 17         Drama
# 78         Crime
# 85     Adventure
# 142    Adventure
# 157        Drama
# 204    Adventure
# 445    Adventure
# 476        Drama
# 630    Biography
# 767       Action
# Name: genre, dtype: object

# %% [markdown]
# # MUTIPLE FILTER CRITERIA

# %% [raw]
# GOAL : Only row who has genre drama and duration grateer than 200

# %%
movies[ (movies.duration>=200) & (movies.genre == "Drama")]
# Out:
#      star_rating               title content_rating  genre  duration  \
# 17           8.7       Seven Samurai        UNRATED  Drama       207
# 157          8.2  Gone with the Wind              G  Drama       238
# 476          7.8              Hamlet          PG-13  Drama       242
#
#                                            actors_list
# 17   [u'Toshir\xf4 Mifune', u'Takashi Shimura', u'K...
# 157  [u'Clark Gable', u'Vivien Leigh', u'Thomas Mit...
# 476  [u'Kenneth Branagh', u'Julie Christie', u'Dere...

# %% [markdown]
#  ### Mutiple condition

# %%
movies[ (movies.genre == "Crime") | (movies.genre == "Drama")| (movies.genre == "Action") ]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# 3            PG-13  Action       152
# 4                R   Crime       154
# ..             ...     ...       ...
# 970              R   Drama       107
# 972          NC-17   Drama       112
# 973          PG-13   Drama       126
# 976          PG-13  Action       138
# 978              R   Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 970  [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# 972  [u'Ryan Gosling', u'Michelle Williams', u'John...
# 973  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [538 rows x 6 columns]

# %% [markdown]
# ##### or

# %%
movies.genre.isin(["Crime","Drama","Action"]) #generates aboolean series
# Out:
# 0       True
# 1       True
# 2       True
# 3       True
# 4       True
#        ...
# 974    False
# 975    False
# 976     True
# 977    False
# 978     True
# Name: genre, Length: 979, dtype: bool

# %%
movies[movies.genre.isin(["Crime","Drama","Action"])]
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 970          7.4                                      Wonder Boys
# 972          7.4                                   Blue Valentine
# 973          7.4                            The Cider House Rules
# 976          7.4  Master and Commander: The Far Side of the World
# 978          7.4                                      Wall Street
#
#     content_rating   genre  duration  \
# 0                R   Crime       142
# 1                R   Crime       175
# 2                R   Crime       200
# 3            PG-13  Action       152
# 4                R   Crime       154
# ..             ...     ...       ...
# 970              R   Drama       107
# 972          NC-17   Drama       112
# 973          PG-13   Drama       126
# 976          PG-13  Action       138
# 978              R   Crime       126
#
#                                            actors_list
# 0    [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1      [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2    [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3    [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4    [u'John Travolta', u'Uma Thurman', u'Samuel L....
# ..                                                 ...
# 970  [u'Michael Douglas', u'Tobey Maguire', u'Franc...
# 972  [u'Ryan Gosling', u'Michelle Williams', u'John...
# 973  [u'Tobey Maguire', u'Charlize Theron', u'Micha...
# 976  [u'Russell Crowe', u'Paul Bettany', u'Billy Bo...
# 978  [u'Charlie Sheen', u'Michael Douglas', u'Tamar...
#
# [538 rows x 6 columns]

# %% [markdown]
# ### READ ONLY SPECIFIC COLS

# %%
# movies= pd.read_csv("http://bit.ly/imdbratings" , usecols=["City","State"]) #or [0,4]

# %% [markdown]
# #### read only few rows

# %%
movies= pd.read_csv("http://bit.ly/imdbratings" , nrows=3)
movies
# Out:
#    star_rating                     title content_rating  genre  duration  \
# 0          9.3  The Shawshank Redemption              R  Crime       142
# 1          9.2             The Godfather              R  Crime       175
# 2          9.1    The Godfather: Part II              R  Crime       200
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...

# %% [markdown]
# ## SELECT ONLY  INT COL

# %%
drinks= pd.read_csv('https://bit.ly//drinksbycountry')

# %%
drinks.to_csv('drinks.csv',index=False)
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
import numpy as np
drinks.select_dtypes(include= [np.number]).dtypes
# Out:
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# dtype: object

# %% [markdown]
#  ### DESCRIBE ONLY SPECIFIC DTYPES

# %%
drinks.describe(include=["float64"])
# Out:
#        total_litres_of_pure_alcohol
# count                    193.000000
# mean                       4.717098
# std                        3.773298
# min                        0.000000
# 25%                        1.300000
# 50%                        4.200000
# 75%                        7.200000
# max                       14.400000

# %% [markdown]
# # Axis parameter

# %%
drinks.drop(2, axis=0).head()
# Out:
#              country  beer_servings  spirit_servings  wine_servings  \
# 0        Afghanistan              0                0              0
# 1            Albania             89              132             54
# 3            Andorra            245              138            312
# 4             Angola            217               57             45
# 5  Antigua & Barbuda            102              128             45
#
#    total_litres_of_pure_alcohol      continent
# 0                           0.0           Asia
# 1                           4.9         Europe
# 3                          12.4         Europe
# 4                           5.9         Africa
# 5                           4.9  North America

# %%
#mean give us a series mean
drinks.mean()
# Out:
# beer_servings                   106.160622
# spirit_servings                  80.994819
# wine_servings                    49.450777
# total_litres_of_pure_alcohol      4.717098
# dtype: float64

# %%
drinks.mean(axis=1)
#0r index or col
# Out:
# 0        0.000
# 1       69.975
# 2        9.925
# 3      176.850
# 4       81.225
#         ...
# 188    110.925
# 189     29.000
# 190      1.525
# 191     14.375
# 192     22.675
# Length: 193, dtype: float64

# %% [markdown]
# # STRING METHODS IN PYTHON

# %%
# orders = pd.read_csv('https://bit.ly//chiporders')

# %%
orders.to_csv('orders.csv',index=False)
#lets make item name uppercase
orders.item_number.str.upper()

# %%
orders.item_number.str.contains("chicken")

# %%
orders[orders.item_number.str.contains("chicken")]

# %% [markdown]
# ### Replace

# %%
order.choice_description.str.replace("[","").str.replace("]","")

# %% [markdown]
# # CHANGE DTYPE OF A PANDAS SERIES

# %%
drinks.dtypes
# Out:
# country                          object
# beer_servings                     int64
# spirit_servings                   int64
# wine_servings                     int64
# total_litres_of_pure_alcohol    float64
# continent                        object
# dtype: object

# %%
drinks["beer_serving"]=drinks.beer_servings.astype(float)
drinks["beer_serving"].dtypes
# Out:
# dtype('float64')

# %% [markdown]
#  ### Change dtype while reading

# %%
drinks= pd.read_csv('https://bit.ly//drinksbycountry',dtype={
    "beer_servings":float
})

# %% [markdown]
# # Example

# %%
orders= pd.read_table('https://bit.ly//chiporders')
orders.to_csv("orders.csv")

# %%
orders.dtypes
# Out:
# order_id               int64
# quantity               int64
# item_name             object
# choice_description    object
# item_price            object
# dtype: object

# %%
orders.item_price.str.replace("$","") 
#still string
# Out:
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98
#          ...
# 4617    11.75
# 4618    11.75
# 4619    11.25
# 4620     8.75
# 4621     8.75
# Name: item_price, Length: 4622, dtype: object

# %%
orders.item_price.str.replace("$","") .astype(float).mean()
# Out:
# 7.464335785374397

# %% [markdown]
# # TRUE OR FALSE AS 0 OR 1

# %%
orders.item_name.str.contains("chicken").astype(int).head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: item_name, dtype: int32

# %% [markdown]
# # GROUP BY

# %%
#what is the avg beer service accross all countries

# %%
drinks.beer_servings.mean()
# Out:
# 106.16062176165804

# %%
#by continent

# %%
drinks.groupby("continent").beer_servings.mean()
# Out:
# continent
# Africa            61.471698
# Asia              37.045455
# Europe           193.777778
# North America    145.434783
# Oceania           89.687500
# South America    175.083333
# Name: beer_servings, dtype: float64

# %%
#filter data
drinks[drinks.continent=="Africa"]
# Out:
#                       country  beer_servings  spirit_servings  wine_servings  \
# 2                     Algeria           25.0                0             14
# 4                      Angola          217.0               57             45
# 18                      Benin           34.0                4             13
# 22                   Botswana          173.0               35             35
# 26               Burkina Faso           25.0                7              7
# 27                    Burundi           88.0                0              0
# 28              Cote d'Ivoire           37.0                1              7
# 29                 Cabo Verde          144.0               56             16
# 31                   Cameroon          147.0                1              4
# 33   Central African Republic           17.0                2              1
# 34                       Chad           15.0                1              1
# 38                    Comoros            1.0                3              1
# 39                      Congo           76.0                1              9
# 47                   DR Congo           32.0                3              1
# 49                   Djibouti           15.0               44              3
# 53                      Egypt            6.0                4              1
# 55          Equatorial Guinea           92.0                0            233
# 56                    Eritrea           18.0                0              0
# 58                   Ethiopia           20.0                3              0
# 62                      Gabon          347.0               98             59
# 63                     Gambia            8.0                0              1
# 66                      Ghana           31.0                3             10
# 70                     Guinea            9.0                0              2
# 71              Guinea-Bissau           28.0               31             21
# 88                      Kenya           58.0               22              2
# 95                    Lesotho           82.0               29              0
# 96                    Liberia           19.0              152              2
# 97                      Libya            0.0                0              0
# 100                Madagascar           26.0               15              4
# 101                    Malawi            8.0               11              1
# 104                      Mali            5.0                1              1
# 107                Mauritania            0.0                0              0
# 108                 Mauritius           98.0               31             18
# 114                   Morocco           12.0                6             10
# 115                Mozambique           47.0               18              5
# 117                   Namibia          376.0                3              1
# 123                     Niger            3.0                2              1
# 124                   Nigeria           42.0                5              2
# 142                    Rwanda           43.0                2              0
# 148       Sao Tome & Principe           56.0               38            140
# 150                   Senegal            9.0                1              7
# 152                Seychelles          157.0               25             51
# 153              Sierra Leone           25.0                3              2
# 158                   Somalia            0.0                0              0
# 159              South Africa          225.0               76             81
# 162                     Sudan            8.0               13              0
# 164                 Swaziland           90.0                2              2
# 172                      Togo           36.0                2             19
# 175                   Tunisia           51.0                3             20
# 179                    Uganda           45.0                9              0
# 183                  Tanzania           36.0                6              1
# 191                    Zambia           32.0               19              4
# 192                  Zimbabwe           64.0               18              4
#
#      total_litres_of_pure_alcohol continent
# 2                             0.7    Africa
# 4                             5.9    Africa
# 18                            1.1    Africa
# 22                            5.4    Africa
# 26                            4.3    Africa
# 27                            6.3    Africa
# 28                            4.0    Africa
# 29                            4.0    Africa
# 31                            5.8    Africa
# 33                            1.8    Africa
# 34                            0.4    Africa
# 38                            0.1    Africa
# 39                            1.7    Africa
# 47                            2.3    Africa
# 49                            1.1    Africa
# 53                            0.2    Africa
# 55                            5.8    Africa
# 56                            0.5    Africa
# 58                            0.7    Africa
# 62                            8.9    Africa
# 63                            2.4    Africa
# 66                            1.8    Africa
# 70                            0.2    Africa
# 71                            2.5    Africa
# 88                            1.8    Africa
# 95                            2.8    Africa
# 96                            3.1    Africa
# 97                            0.0    Africa
# 100                           0.8    Africa
# 101                           1.5    Africa
# 104                           0.6    Africa
# 107                           0.0    Africa
# 108                           2.6    Africa
# 114                           0.5    Africa
# 115                           1.3    Africa
# 117                           6.8    Africa
# 123                           0.1    Africa
# 124                           9.1    Africa
# 142                           6.8    Africa
# 148                           4.2    Africa
# 150                           0.3    Africa
# 152                           4.1    Africa
# 153                           6.7    Africa
# 158                           0.0    Africa
# 159                           8.2    Africa
# 162                           1.7    Africa
# 164                           4.7    Africa
# 172                           1.3    Africa
# 175                           1.3    Africa
# 179                           8.3    Africa
# 183                           5.7    Africa
# 191                           2.5    Africa
# 192                           4.7    Africa

# %%
drinks[drinks.continent=="Africa"].beer_servings.mean()

#max , min
# Out:
# 61.471698113207545

# %% [markdown]
# when should use group by?
# - analyze some pandas series by some category
# - in this case it is category

# %% [markdown]
# ###### AGG
# - allow us to specify mul agg fun at once

# %%
drinks[drinks.continent=="Africa"].beer_servings.agg(["count","min","max","mean"])
# Out:
# count     53.000000
# min        0.000000
# max      376.000000
# mean      61.471698
# Name: beer_servings, dtype: float64

# %% [markdown]
# ###### Apply to all colums

# %%
drinks.groupby("continent").mean()
# Out:
#                beer_servings  spirit_servings  wine_servings  \
# continent
# Africa             61.471698        16.339623      16.264151
# Asia               37.045455        60.840909       9.068182
# Europe            193.777778       132.555556     142.222222
# North America     145.434783       165.739130      24.521739
# Oceania            89.687500        58.437500      35.625000
# South America     175.083333       114.750000      62.416667
#
#                total_litres_of_pure_alcohol
# continent
# Africa                             3.007547
# Asia                               2.170455
# Europe                             8.617778
# North America                      5.995652
# Oceania                            3.381250
# South America                      6.308333

# %%
# %matplotlib inline
drinks.groupby("continent").mean().plot(kind="bar")

# %% [markdown]
# # EXPLORE PANDAS SERIES

# %%
movies.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
#genre , duration

movies.genre.describe()
# Out:
# count         3
# unique        1
# top       Crime
# freq          3
# Name: genre, dtype: object

# %%
movies.genre.value_counts()
# Out:
# Crime    3
# Name: genre, dtype: int64

# %%
movies.genre.value_counts(normalize= True)
# Out:
# Crime    1.0
# Name: genre, dtype: float64

# %%
movies.genre.unique()
# Out:
# array(['Crime'], dtype=object)

# %%
movies.genre.nunique() #no of unique
# Out:
# 1

# %%
pd.crosstab(movies.genre, movies.content_rating)
# Out:
# content_rating  R
# genre
# Crime           3

# %% [markdown]
# ##### numeric col

# %%
movies.duration.describe()
# Out:
# count      3.000000
# mean     172.333333
# std       29.091809
# min      142.000000
# 25%      158.500000
# 50%      175.000000
# 75%      187.500000
# max      200.000000
# Name: duration, dtype: float64

# %%
movies.duration.value_counts() 
#shows here no of movies that have this no of duration
# Out:
# 175    1
# 142    1
# 200    1
# Name: duration, dtype: int64

# %% [markdown]
# ###### VISIUALIZATION

# %%
movies.duration.plot(kind="bar")

# %%
movies.genre.value_counts().plot(kind="bar")

# %% [markdown]
#    # HANDLE MISSING VALUE

# %%
ufo=pd.read_csv("http://bit.ly//uforeports")

# %%
ufo.isnull().tail()
#true if missing
# Out:
#         City  Colors Reported  Shape Reported  State   Time
# 18236  False             True           False  False  False
# 18237  False             True           False  False  False
# 18238  False             True            True  False  False
# 18239  False            False           False  False  False
# 18240  False             True           False  False  False

# %%
ufo.notnull().tail()
# Out:
#        City  Colors Reported  Shape Reported  State  Time
# 18236  True            False            True   True  True
# 18237  True            False            True   True  True
# 18238  True            False           False   True  True
# 18239  True             True            True   True  True
# 18240  True            False            True   True  True

# %% [markdown]
# ###### check no of missing values in each columns

# %%
ufo.isnull().sum()
#colum sum axis=0
# Out:
# City                  25
# Colors Reported    15359
# Shape Reported      2644
# State                  0
# Time                   0
# dtype: int64

# %%
pd.Series([True,False,True]).sum()
# Out:
# 2

# %%
ufo[ufo.City.isnull()] #25 rows
# Out:
#       City Colors Reported Shape Reported State              Time
# 21     NaN             NaN            NaN    LA    8/15/1943 0:00
# 22     NaN             NaN          LIGHT    LA    8/15/1943 0:00
# 204    NaN             NaN           DISK    CA   7/15/1952 12:30
# 241    NaN            BLUE           DISK    MT    7/4/1953 14:00
# 613    NaN             NaN           DISK    NV    7/1/1960 12:00
# 1877   NaN          YELLOW         CIRCLE    AZ    8/15/1969 1:00
# 2013   NaN             NaN            NaN    NH     8/1/1970 9:30
# 2546   NaN             NaN       FIREBALL    OH  10/25/1973 23:30
# 3123   NaN             RED       TRIANGLE    WV  11/25/1975 23:00
# 4736   NaN             NaN         SPHERE    CA   6/23/1982 23:00
# 5269   NaN             NaN            NaN    AZ   6/30/1985 21:30
# 6735   NaN             NaN      FORMATION    TX     4/1/1992 2:00
# 7208   NaN             NaN         CIRCLE    MI   10/4/1993 17:30
# 8828   NaN             NaN       TRIANGLE    WA  10/30/1995 21:30
# 8967   NaN             NaN        VARIOUS    CA   12/8/1995 18:00
# 9273   NaN             NaN       TRIANGLE    OH     5/1/1996 3:00
# 9388   NaN             NaN           OVAL    CA   6/12/1996 12:00
# 9587   NaN             NaN            EGG    FL   8/24/1996 15:00
# 10399  NaN             NaN       TRIANGLE    IL   6/15/1997 23:00
# 11625  NaN             NaN         CIRCLE    TX     6/7/1998 7:00
# 12441  NaN             RED       FIREBALL    WA  10/26/1998 17:58
# 15767  NaN             NaN      RECTANGLE    NV   1/21/2000 11:30
# 15812  NaN             NaN          LIGHT    NV     2/2/2000 3:00
# 16054  NaN           GREEN            NaN    FL    3/11/2000 3:30
# 16608  NaN             NaN         SPHERE    NY   6/15/2000 15:00

# %% [markdown]
# # options
# - drop missing row

# %%
ufo.shape
# Out:
# (18241, 5)

# %%
#drop a row if any of value is missing
ufo.dropna(how="any").shape
#all : if all values are missing
# Out:
# (2486, 5)

# %%
#want to drop a row if any city or shape reported is missing
ufo.dropna(subset=['City','Shape Reported'], how ='any').shape
# Out:
# (15576, 5)

# %% [markdown]
# # Filling

# %%
ufo['Shape Reported'].value_counts()
#how many time a value occur
#missing values are by default excluded
# Out:
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# HEXAGON         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %%
ufo['Shape Reported'].value_counts(dropna=False)
# Out:
# LIGHT        2803
# NaN          2644
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# VARIOUS       333
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# FLARE           1
# PYRAMID         1
# HEXAGON         1
# DOME            1
# Name: Shape Reported, dtype: int64

# %%
ufo["Shape Reported"].fillna(value="VARIOUS",inplace=True)

# %%
ufo['Shape Reported'].value_counts(dropna=False)
#various count update
# Out:
# VARIOUS      2977
# LIGHT        2803
# DISK         2122
# TRIANGLE     1889
# OTHER        1402
# CIRCLE       1365
# SPHERE       1054
# FIREBALL     1039
# OVAL          845
# CIGAR         617
# FORMATION     434
# RECTANGLE     303
# CYLINDER      294
# CHEVRON       248
# DIAMOND       234
# EGG           197
# FLASH         188
# TEARDROP      119
# CONE           60
# CROSS          36
# DELTA           7
# ROUND           2
# CRESCENT        2
# DOME            1
# PYRAMID         1
# HEXAGON         1
# FLARE           1
# Name: Shape Reported, dtype: int64

# %% [markdown]
# # PANDAS INDEX

# %%
drinks.index
#row labels
# Out:
# RangeIndex(start=0, stop=193, step=1)

# %%
pd.read_table("http://bit.ly/movieusers",sep="|",header=None).head()
# Out:
#    0   1  2           3      4
# 0  1  24  M  technician  85711
# 1  2  53  F       other  94043
# 2  3  23  M      writer  32067
# 3  4  24  M  technician  43537
# 4  5  33  F       other  15213

# %% [markdown]
# ##### IDENTIFICATION

# %%
drinks=pd.read_csv("drinks.csv")
drinks[drinks.continent=='South America']
# Out:
#        country  beer_servings  spirit_servings  wine_servings  \
# 6    Argentina            193               25            221
# 20     Bolivia            167               41              8
# 23      Brazil            245              145             16
# 35       Chile            130              124            172
# 37    Colombia            159               76              3
# 52     Ecuador            162               74              3
# 72      Guyana             93              302              1
# 132   Paraguay            213              117             74
# 133       Peru            163              160             21
# 163   Suriname            128              178              7
# 185    Uruguay            115               35            220
# 188  Venezuela            333              100              3
#
#      total_litres_of_pure_alcohol      continent
# 6                             8.3  South America
# 20                            3.8  South America
# 23                            7.2  South America
# 35                            7.6  South America
# 37                            4.2  South America
# 52                            4.2  South America
# 72                            7.1  South America
# 132                           7.3  South America
# 133                           6.1  South America
# 163                           5.6  South America
# 185                           6.6  South America
# 188                           7.7  South America

# %% [markdown]
# ##### SELECTION

# %%
# drinks.loc[23,"beer_servings"]

# %%
drinks.set_index("country",inplace=True)
#county is no longer a col 
#not a part of df
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# country
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# country
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# Andorra                              12.4         Europe
# Angola                                5.9         Africa
# ...                                   ...            ...
# Venezuela                             7.7  South America
# Vietnam                               2.0           Asia
# Yemen                                 0.1           Asia
# Zambia                                2.5         Africa
# Zimbabwe                              4.7         Africa
#
# [193 rows x 5 columns]

# %%
drinks.continent.head() #see index is country
# Out:
# country
# Afghanistan      Asia
# Albania        Europe
# Algeria        Africa
# Andorra        Europe
# Angola         Africa
# Name: continent, dtype: object

# %%
drinks.continent.value_counts()
# Out:
# Africa           53
# Europe           45
# Asia             44
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.continent.value_counts()["Africa"]
# Out:
# 53

# %% [markdown]
# ### Sort Index

# %%
drinks.continent.value_counts().sort_index()
# Out:
# Africa           53
# Asia             44
# Europe           45
# North America    23
# Oceania          16
# South America    12
# Name: continent, dtype: int64

# %%
drinks.loc["Brazil","beer_servings"]
# Out:
# 245

# %% [markdown]
# # Alignment

# %%
people=pd.Series([2000,34000], index=["Albania",'Andorra'], name="popu")
people
# Out:
# Albania     2000
# Andorra    34000
# Name: popu, dtype: int64

# %%
drinks.beer_servings*people
# Out:
# Afghanistan          NaN
# Albania         178000.0
# Algeria              NaN
# Andorra        8330000.0
# Angola               NaN
#                  ...
# Venezuela            NaN
# Vietnam              NaN
# Yemen                NaN
# Zambia               NaN
# Zimbabwe             NaN
# Length: 193, dtype: float64

# %%
pd.concat([drinks,people],axis=1).head()
# Out:
# C:\Users\DANIA NIAZI\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
#
#              total_litres_of_pure_alcohol continent     popu
# Afghanistan                           0.0      Asia      NaN
# Albania                               4.9    Europe   2000.0
# Algeria                               0.7    Africa      NaN
# Andorra                              12.4    Europe  34000.0
# Angola                                5.9    Africa      NaN

# %%
drinks.index.name=None
drinks
# Out:
#              beer_servings  spirit_servings  wine_servings  \
# Afghanistan              0                0              0
# Albania                 89              132             54
# Algeria                 25                0             14
# Andorra                245              138            312
# Angola                 217               57             45
# ...                    ...              ...            ...
# Venezuela              333              100              3
# Vietnam                111                2              1
# Yemen                    6                0              0
# Zambia                  32               19              4
# Zimbabwe                64               18              4
#
#              total_litres_of_pure_alcohol      continent
# Afghanistan                           0.0           Asia
# Albania                               4.9         Europe
# Algeria                               0.7         Africa
# Andorra                              12.4         Europe
# Angola                                5.9         Africa
# ...                                   ...            ...
# Venezuela                             7.7  South America
# Vietnam                               2.0           Asia
# Yemen                                 0.1           Asia
# Zambia                                2.5         Africa
# Zimbabwe                              4.7         Africa
#
# [193 rows x 5 columns]

# %% [markdown]
# ###### MOVE BACK

# %%
drinks.index.name="Country"
drinks.reset_index(inplace=True)
drinks.head()
# Out:
#        Country  beer_servings  spirit_servings  wine_servings  \
# 0  Afghanistan              0                0              0
# 1      Albania             89              132             54
# 2      Algeria             25                0             14
# 3      Andorra            245              138            312
# 4       Angola            217               57             45
#
#    total_litres_of_pure_alcohol continent
# 0                           0.0      Asia
# 1                           4.9    Europe
# 2                           0.7    Africa
# 3                          12.4    Europe
# 4                           5.9    Africa

# %%
drinks.describe().index #it is a dataframe and has index
# Out:
# Index(['count', 'mean', 'std', 'min', '25%', '50%', '75%', 'max'], dtype='object')

# %%
drinks.describe().loc["25%","beer_servings"] #describe givesus a dataframe
# Out:
# 20.0
